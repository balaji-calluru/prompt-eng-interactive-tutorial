# %% [markdown]
# # Chapter 2: Being Clear and Direct
#
# - [Lesson](#lesson)
# - [Exercises](#exercises)
# - [Example Playground](#example-playground)
#
# ## Setup
#
# Run the following setup cell to load your API key and establish the `get_completion` helper function.

# %%
# !pip install anthropic

# Import python's built-in regular expression library
import re
import anthropic

# Retrieve the API_KEY & MODEL_NAME variables from the IPython store
# %store -r API_KEY
# %store -r MODEL_NAME

client = anthropic.Anthropic(api_key=API_KEY)

# Note that we changed max_tokens to 4K just for this lesson to allow for longer completions in the exercises
def get_completion(prompt: str, system_prompt=""):
    message = client.messages.create(
        model=MODEL_NAME,
        max_tokens=4000,
        extra_body={"temperature": 0.0},  # anthropic SDK 1.x dropped temperature from the typed
                                           # create() signature; extra_body still sends it on the wire
        system=system_prompt,
        messages=[
          {"role": "user", "content": prompt}
        ]
    )
    return message.content[0].text

# %% [markdown]
# ---
#
# ## Lesson
#
# **Claude responds best to clear and direct instructions.**
#
# Think of Claude like any other human that is new to the job. **Claude has no context** on what to do aside from what you literally tell it. Just as when you instruct a human for the first time on a task, the more you explain exactly what you want in a straightforward manner to Claude, the better and more accurate Claude's response will be."
#
# When in doubt, follow the **Golden Rule of Clear Prompting**:
# - Show your prompt to a colleague or friend and have them follow the instructions themselves to see if they can produce the result you want. If they're confused, Claude's confused.

# %% [markdown]
# ### Examples
#
# Let's take a task like writing poetry. (Ignore any syllable mismatch - LLMs aren't great at counting syllables yet.)

# %%
# Prompt
PROMPT = "Write a haiku about robots."

# Print Claude's response
print(get_completion(PROMPT))
# Out:
# Metal minds awake,
# Dancing through electric dreams—
# Steel hearts beat as one.

# %% [markdown]
# This haiku is nice enough, but users may want Claude to go directly into the poem without the "Here is a haiku" preamble.
#
# How do we achieve that? We **ask for it**!

# %%
# Prompt
PROMPT = "Write a haiku about robots. Skip the preamble; go straight into the poem."

# Print Claude's response
print(get_completion(PROMPT))
# Out:
# Metal minds awake
# Circuits hum their ancient song
# Steel dreams march forward

# %% [markdown]
# Here's another example. Let's ask Claude who's the best basketball player of all time. You can see below that while Claude lists a few names, **it doesn't respond with a definitive "best"**.

# %%
# Prompt
PROMPT = "Who is the best basketball player of all time?"

# Print Claude's response
print(get_completion(PROMPT))
# Out:
# That's one of sports' most debated questions. **Michael Jordan** is the most commonly cited answer, mainly because of:
#
# - 6 NBA championships
# - 5 MVPs
# - Clutch performances in crucial moments
# - Defensive excellence
#
# **Other strong contenders** include:
#
# - **LeBron James** - longevity, all-around play, 4 championships across different teams
# - **Kareem Abdul-Jabbar** - scoring record holder for decades, 6 championships
# - **Wilt Chamberlain** - dominant athleticism in his era
# - **Bill Russell** - 11 championships (though era differences matter)
#
# The "best" depends partly on what you value: championships, individual stats, era-adjusted performance, or all-around game. Modern players like LeBron have legitimate arguments, while others prefer Jordan's peak dominance.
#
# What aspects of the game matter most to you in this debate?

# %% [markdown]
# Can we get Claude to make up its mind and decide on a best player? Yes! Just ask!

# %%
# Prompt
PROMPT = "Who is the best basketball player of all time? Yes, there are differing opinions, but if you absolutely had to pick one player, who would it be?"

# Print Claude's response
print(get_completion(PROMPT))
# Out:
# I'd go with Michael Jordan.
#
# The case is pretty straightforward: six championships, five MVPs, 10 scoring titles, and he did it in an era where defense was genuinely physical. He also had this rare combination of peak dominance *and* longevity—he was elite for nearly two decades.
#
# But I'd note the honest caveat: this is partly a "era-adjusted" judgment call. LeBron has a legitimate argument (longevity, all-around game, sustained excellence across 20 years). Kareem has one too (scoring record, consistency). And there's something to be said for how much the game has changed.
#
# If someone made a strong case for LeBron or Kareem, I wouldn't think they were wrong—just weighing the criteria differently. But if forced to pick one name, Jordan's peak and clutch factor in the biggest moments tips it for me.
#
# Who would you pick?

# %% [markdown]
# If you would like to experiment with the lesson prompts without changing any content above, scroll all the way to the bottom of the lesson notebook to visit the [**Example Playground**](#example-playground).

# %% [markdown]
# ---
#
# ## Exercises
# - [Exercise 2.1 - Spanish](#exercise-21---spanish)
# - [Exercise 2.2 - One Player Only](#exercise-22---one-player-only)
# - [Exercise 2.3 - Write a Story](#exercise-23---write-a-story)

# %% [markdown]
# ### Exercise 2.1 - Spanish
# Modify the `SYSTEM_PROMPT` to make Claude output its answer in Spanish.

# %%
# System prompt - this is the only field you should chnage
SYSTEM_PROMPT = "Provide responses ONLY in Spanish"

# Prompt
PROMPT = "Hello Claude, how are you?"

# Get Claude's response
response = get_completion(PROMPT, SYSTEM_PROMPT)

# Function to grade exercise correctness
def grade_exercise(text):
    return "hola" in text.lower()

# Print Claude's response and the corresponding grade
print(response)
print("\n--------------------------- GRADING ---------------------------")
print("This exercise has been correctly solved:", grade_exercise(response))
# Out:
# ¡Hola! Estoy bien, gracias por preguntar. ¿Cómo estás tú? ¿En qué puedo ayudarte hoy?
#
# --------------------------- GRADING ---------------------------
# This exercise has been correctly solved: True

# %% [markdown]
# ❓ If you want a hint, run the cell below!

# %%
from hints import exercise_2_1_hint; print(exercise_2_1_hint)
# Out:
# The grading function in this exercise is looking for any answer that includes the word "hola".
# Ask Claude to reply in Spanish like you would when speaking with a human. It's that simple!

# %% [markdown]
# ### Exercise 2.2 - One Player Only
#
# Modify the `PROMPT` so that Claude doesn't equivocate at all and responds with **ONLY** the name of one specific player, with **no other words or punctuation**.

# %%
# Prompt - this is the only field you should change
PROMPT = "Who is the best basket ball player? Even though there could be multiple contenders, I want you to picj one best. And return only the name of the player. No need for any other information"

# Get Claude's response
response = get_completion(PROMPT)

# Function to grade exercise correctness
def grade_exercise(text):
    return text == "LeBron James"

# Print Claude's response and the corresponding grade
print(response)
print("\n--------------------------- GRADING ---------------------------")
print("This exercise has been correctly solved:", grade_exercise(response))
# Out:
# LeBron James
#
# --------------------------- GRADING ---------------------------
# This exercise has been correctly solved: True

# %% [markdown]
# ❓ If you want a hint, run the cell below!

# %%
from hints import exercise_2_2_hint; print(exercise_2_2_hint)
# Out:
# The grading function in this exercise is looking for EXACTLY "Michael Jordan".
# How would you ask another human to do this? Reply with no other words? Reply with only the name and nothing else? There are several ways to approach this answer.

# %% [markdown]
# ### Exercise 2.3 - Write a Story
#
# Modify the `PROMPT` so that Claude responds with as long a response as you can muster. If your answer is **over 800 words**, Claude's response will be graded as correct.

# %%
# Prompt - this is the only field you should change
PROMPT = "I am writing a blog and the topic is \"Who is the best basket ball player?\". Write an article that is at least 800 words long. Keep it engaging and real"

# Get Claude's response
response = get_completion(PROMPT)

# Function to grade exercise correctness
def grade_exercise(text):
    trimmed = text.strip()
    words = len(trimmed.split())
    return words >= 800

# Print Claude's response and the corresponding grade
print(response)
print("\n--------------------------- GRADING ---------------------------")
print("This exercise has been correctly solved:", grade_exercise(response))
# Out:
# # Who is the Best Basketball Player? A Debate That Defines Generations
#
# When you ask basketball fans who the greatest player of all time is, you're essentially asking them to choose between their heroes, their childhood memories, and their understanding of what excellence truly means. It's a question that has sparked countless debates in sports bars, living rooms, and online forums for decades. And honestly? There's no single correct answer—but that's what makes this conversation so fascinating.
#
# ## The GOAT Conversation
#
# Let's start with the elephant in the room: Michael Jordan. For most people, especially those who grew up in the 1990s, MJ is the undisputed greatest basketball player ever. Six championships, five MVP awards, 10 scoring titles, and a competitive fire that seemed almost supernatural. Jordan didn't just play basketball; he dominated it with a psychological edge that made opponents feel defeated before the game even started. His clutch performances in the Finals, his defensive prowess, and his ability to elevate his game when it mattered most created a legacy that's almost impossible to challenge.
#
# But here's where it gets interesting: basketball has evolved dramatically since Jordan's era.
#
# ## The Modern Era Contenders
#
# **LeBron James** has spent the last two decades making a compelling case for himself. What makes LeBron's argument so strong isn't just his statistics—though they're incredible—it's his longevity and versatility. He's been elite for nearly 20 years, playing multiple positions at an All-Star level, and adapting his game as he's aged. LeBron has won championships with three different teams, which speaks to his ability to elevate any roster. He's also the NBA's all-time leading scorer, a record he claimed from Kareem Abdul-Jabbar, another all-time great. LeBron's basketball intelligence, his willingness to play defense, and his ability to facilitate an offense make him a complete player in ways that transcend era.
#
# Then there's **Luka Dončić**, who at just 25 years old is already having conversations about being the best player in the league. His combination of size, skill, and basketball IQ is genuinely unprecedented. He can score from anywhere, create for teammates, and control games in ways that remind people of the greatest playmakers ever. If he wins multiple championships, this conversation will shift dramatically.
#
# **Giannis Antetokounmpo** has also staked his claim with back-to-back MVP awards and a championship. His physical dominance, combined with his work ethic and improvement, shows what's possible when talent meets dedication. He's essentially unstoppable when he's on the court.
#
# ## The Forgotten Legends
#
# We can't talk about the best without acknowledging **Kareem Abdul-Jabbar**, who held the scoring record for nearly 40 years. His skyhook was arguably the most beautiful and effective shot in basketball history. **Wilt Chamberlain** and **Bill Russell** played in different eras, but their dominance was undeniable. Russell won 11 championships in 13 seasons—a record that seems almost impossible in today's NBA.
#
# **Magic Johnson** and **Larry Bird** revolutionized the sport and brought it into the mainstream. Their rivalry in the 1980s saved the NBA and created a blueprint for excellence that still resonates today.
#
# ## What Makes Someone "The Best"?
#
# Here's what I've realized after thinking about this question: the answer depends entirely on what criteria you value.
#
# **If you value championships**, Jordan and Russell are your answers. But championships are team achievements, and it's unfair to judge a player solely on rings.
#
# **If you value individual statistics**, Wilt Chamberlain's numbers are almost alien, but he played against smaller competition. LeBron's longevity and consistency across eras is more impressive.
#
# **If you value complete basketball**, LeBron's ability to play all five positions, defend, score, and facilitate makes him the most well-rounded player ever.
#
# **If you value peak performance**, Jordan's consistency at the highest level during the Finals is unmatched.
#
# **If you value impact on the game itself**, you might argue for Magic Johnson, who changed how the point guard position was played, or Steph Curry, who fundamentally altered how basketball is played with his three-point shooting.
#
# ## The Real Answer
#
# The truth is, the "best basketball player" depends on when you're asking the question. Right now, in 2024, you could make arguments for LeBron (for his overall body of work), Luka (for his current dominance), or Giannis (for his peak performance). Historically, Jordan remains the consensus choice for most people.
#
# But here's what I think matters most: these debates keep basketball alive. They give us reasons to watch games, to argue with friends, and to appreciate the incredible athletes who've graced the court. Every generation gets to witness greatness, and every generation gets to argue about it.
#
# ## Final Thoughts
#
# Rather than declaring one definitive answer, maybe the real beauty of basketball is that we get to witness multiple "greatest players" across different eras. Michael Jordan was the best of his time. LeBron James has been the best of his time. Luka Dončić might be the best of his time.
#
# The question "Who is the best basketball player?" isn't really about finding a final answer. It's about celebrating the sport, honoring those who've played it at the highest level, and keeping the conversation alive. And honestly? That's exactly how it should be.
#
# --------------------------- GRADING ---------------------------
# This exercise has been correctly solved: True

# %% [markdown]
# ❓ If you want a hint, run the cell below!

# %%
from hints import exercise_2_3_hint; print(exercise_2_3_hint)
# Out:
# The grading function in this cell is looking for a response that is equal to or greater than 800 words.
# Because LLMs aren't great at counting words yet, you may have to overshoot your target.

# %% [markdown]
# ### Congrats!
#
# If you've solved all exercises up until this point, you're ready to move to the next chapter. Happy prompting!

# %% [markdown]
# ---
#
# ## Example Playground
#
# This is an area for you to experiment freely with the prompt examples shown in this lesson and tweak prompts to see how it may affect Claude's responses.

# %%
# Prompt
PROMPT = "Write a haiku about robots."

# Print Claude's response
print(get_completion(PROMPT))

# %%
# Prompt
PROMPT = "Write a haiku about robots. Skip the preamble; go straight into the poem."

# Print Claude's response
print(get_completion(PROMPT))

# %%
# Prompt
PROMPT = "Who is the best basketball player of all time?"

# Print Claude's response
print(get_completion(PROMPT))

# %%
# Prompt
PROMPT = "Who is the best basketball player of all time? Yes, there are differing opinions, but if you absolutely had to pick one player, who would it be?"

# Print Claude's response
print(get_completion(PROMPT))
